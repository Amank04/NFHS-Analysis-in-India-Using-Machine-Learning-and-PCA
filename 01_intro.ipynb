# %%
import pandas as pd

df = pd.read_csv('NHS-5_2019-20.csv')
pd.options.display.max_columns = 110

df.columns = range(df.shape[1])


df[1] = pd.factorize(df[1])[0]
# df.drop([0,2,3], axis=0)

# df

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import statsmodels.api as sm 
import seaborn as sns

# %% [markdown]
# ### Women Age Group 15 To 49 Years Who Are Literate (%) (UOM:%(Percentage)) - Bad

# %%
y=df[97]
# 0 input features
# y.fillna(y.mean(),axis=0)
# y.info()
x1=df.drop([0,2,3], axis=1)
# pd.options.display.max_rows = 150
x1 = x1.apply(lambda col: col.fillna(col.mean()), axis=0)



x=sm.add_constant(x1)
results=sm.OLS(y,x).fit() 
# results.summary()

# %% [markdown]
# ### Linear correlation b/w indicators.

# %%
correlation_matrix = x1.corr()
correlation_matrix
# Out:
#           1         4         5         6         7         8         9    \
# 1    1.000000 -0.001759 -0.012859 -0.038076  0.102814 -0.004720  0.073640
# 4   -0.001759  1.000000  0.912577  0.083086  0.112988 -0.363714  0.139522
# 5   -0.012859  0.912577  1.000000  0.064564  0.078326 -0.400048  0.150326
# 6   -0.038076  0.083086  0.064564  1.000000  0.751477 -0.254712  0.360720
# 7    0.102814  0.112988  0.078326  0.751477  1.000000 -0.376395  0.474489
# ..        ...       ...       ...       ...       ...       ...       ...
# 103 -0.011232 -0.086286  0.021971  0.053651  0.116727  0.111289  0.387429
# 104  0.014690 -0.146910 -0.037774  0.075158  0.129772  0.105388  0.377561
# 105  0.007299 -0.281183 -0.260792  0.131056  0.212949  0.259449  0.267162
# 106 -0.038266 -0.287507 -0.302977  0.212083  0.238223  0.196640  0.185612
# 107 -0.043291 -0.296310 -0.256874  0.110316  0.090653  0.209440  0.037484
#
#           10        11        12        13        14        15        16   \
# ...

# %% [markdown]
# ### Births In Public Health Facility Delivered By Caesarean Section (%) - 2

# %%
y=df[12]
# y.info()
# 2 input features

x=sm.add_constant(x1)
results=sm.OLS(y,x).fit() 
# results.summary()

# %% [markdown]
# ### Children Under 5 Years Who Are Underweight (%) - Good

# %%
y=df[34]
# y.info()


x=sm.add_constant(x1)
results=sm.OLS(y,x).fit() 
# results.summary()

# %% [markdown]
# ### Women Unmet Need For Spacing (%) - Good

# %%
y=df[91]
# y.info()


x=sm.add_constant(x1)
results=sm.OLS(y,x).fit() 
# results.summary()

# %% [markdown]
# ### Pregnant Women Age Group 15 To 49 Years Who Are Anaemic (%) - Very Good

# %%
y=df[83]
y = y.fillna(y.mean(),axis=0) # replacing null values with its mean.
# y.info()
x=sm.add_constant(x1)
results=sm.OLS(y,x).fit() 
# results.summary()

# %% [markdown]
# ### Population Living In Households That Use An Improved Sanitation Facility (%) - 2

# %%
y=df[80]
# 1-2 input feature
x=sm.add_constant(x1)
results=sm.OLS(y,x).fit() 
# results.params
# results.summary()

# %% [markdown]
# ### Current Users Ever Told About Side Effects Of Current Method (%) - 1

# %%
y=df[45]
# only 1 input feature

y = y.fillna(y.mean(),axis=0) # replacing null values with its mean.
# y.info()
x=sm.add_constant(x1)
results=sm.OLS(y,x).fit() 
# results.summary()

# %% [markdown]
# ### Households Using Clean Fuel For Cooking (%) - Good

# %%
y=df[54]
# only 1 input feature

# y = y.fillna(y.mean(),axis=0) # replacing null values with its mean.
# y.info()
x=sm.add_constant(x1)
results=sm.OLS(y,x).fit() 
# results.summary()

# %% [markdown]
# ###  Non-Pregnant Women Age Group 15 To 49 Years Who Are Anaemic (%) - Bad

# %%
y=df[77]
# only 1 input feature

# y = y.fillna(y.mean(),axis=0) # replacing null values with its mean.
# y.info()
x=sm.add_constant(x1)
results=sm.OLS(y,x).fit() 
# results.summary()

# %% [markdown]
# ### Mothers Who Received Postnatal Care From A Doctor Or Nurse Or Lady Health Visitor ( Lhv ) Or Auxiliary Nurse Midwifery ( Anm ) Or Midwife Or Other Health Personnel Within 2 Days Of Delivery (%) - Good

# %%
y=df[74]
# only 1 input feature

# y = y.fillna(y.mean(),axis=0) # replacing null values with its mean.
# y.info()
x=sm.add_constant(x1)
results=sm.OLS(y,x).fit() 
# results.summary()

# %% [markdown]
# ### Married Women Age Group 15 To 49 Years Unmet Need For Family Planning (%) - good

# %%
y=df[90]
# only 1 input feature

# y = y.fillna(y.mean(),axis=0) # replacing null values with its mean.
# y.info()
x=sm.add_constant(x1)
results=sm.OLS(y,x).fit() 
# results.summary()

# %% [markdown]
# ### Children Under Age 5 Years Whose Birth Was Registered With The Civil Authority (%) - good

# %%
y=df[37]
# only 1 input feature

# y = y.fillna(y.mean(),axis=0) # replacing null values with its mean.
# y.info()
x=sm.add_constant(x1)
results=sm.OLS(y,x).fit() 
# results.summary()

# %% [markdown]
# ### Children Age Group 6 To 23 Months Receiving An Adequate Diet (%) - bad

# %%
y=df[89]
# only 1 input feature

y = y.fillna(y.mean(),axis=0) # replacing null values with its mean.
# y.info()
x=sm.add_constant(x1)
results=sm.OLS(y,x).fit() 
# results.summary()

# %% [markdown]
# ### Births Delivered By Caesarean Section (%) - bad

# %%
y=df[10]
# only 1 input feature

# y = y.fillna(y.mean(),axis=0) # replacing null values with its mean.
# y.info()
x=sm.add_constant(x1)
results=sm.OLS(y,x).fit() 
# results.summary()

# %% [markdown]
# ### Children Age Group 12 To 23 Months Who Received Bacillus Calmette Guerin (BCG) Vaccine (%) - Bad

# %%
y=df[10]
# only 1 input feature

# y = y.fillna(y.mean(),axis=0) # replacing null values with its mean.
# y.info()
x=sm.add_constant(x1)
results=sm.OLS(y,x).fit() 
# results.summary()

# %% [markdown]
# ### Children Age Group 12 To 23 Months Who Have Received Bacillus Calmette Guerin ( Bcg) (%) - Bad

# %%
y=df[21]
# only 1 input feature

y = y.fillna(y.mean(),axis=0) # replacing null values with its mean.
# y.info()
x=sm.add_constant(x1)
results=sm.OLS(y,x).fit() 
# results.summary()
